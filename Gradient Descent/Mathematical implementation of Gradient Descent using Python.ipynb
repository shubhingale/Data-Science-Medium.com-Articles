# %% [markdown]
# # Mathematical implementation of Gradient Descent using Python
# ### Following is the problem statement to implement gradient descent.
# 1. Cost function : $f(x) = x^3 -4x^2+6$
# 2. An equation of slope(Find derivative of cost function $f(x)$ w.r.t. $x$. $f'(x) = 3x^2-8x$
# 3. Updation Rule is as follows
#
# <center><I>Next weight = Existing Weight - Learning Rate * Gradient</I>
#
#     OR
# $$x_{k+1}=x_k- \alpha f'(x_k)$$
#
# Let us assume initial values of $x_k$ and  $\alpha$ as 0.5 and 0.05 respectively.
#
# <b>Step 1:</b> Define $f'(x)$ and $x_{k+1}$ equations.

# %%
f_x = lambda x: pow(x,3)-(4*pow(x,2))+6
fd_x = lambda x: (3*pow(x,2))-(8*x)
Calculate_X_next = lambda x_k:x_k - (learning_rate * fd_x(x_k))

# %% [markdown]
# <b>Step 2:</b> Iteratively, calculate $x_k$ and $f'(x)$, till it stops changing value of $x_k$.

# %%
import pandas as pd
# def gradient_descent(x_k,learning_rate, iterations):
def gradient_descent(x_k,learning_rate, iterations):
    df = pd.DataFrame(columns={'X_k','fd_x'})
    df = df.astype(float)
    df = df.append({'X_k':x_k,'fd_x':fd_x(x_k)},ignore_index=True
    )
    for i in range(iterations):
        x_k = Calculate_X_next(x_k)
        df = df.append({'X_k':x_k,'fd_x':fd_x(x_k)},ignore_index=True
    )
    return df

# %% [markdown]
# <b>Step 3:</b> Plot a plot $f'(x)$ vs $x_{k}$.

# %%
import matplotlib.pyplot as plt
import numpy as np
learning_rate = 0.05
df = gradient_descent(0.3,learning_rate, 35)
fig, ax = plt.subplots()
mark = [df.fd_x.idxmin()]
ax.plot(df.X_k, df.fd_x)
ax.plot(df.X_k, df.fd_x,markevery=mark, ls="", marker="o", label="points")

def annot_min(x,y, ax=None):
    xmin = x[df.fd_x.idxmin()]
    ymin = y[df.fd_x.idxmin()]
    text= "x={:.3f}, y={:.3f}".format(xmin, ymin)
    if not ax:
        ax=plt.gca()
    bbox_props = dict(boxstyle="square,pad=0.3", fc="w", ec="k", lw=0.72)
    arrowprops=dict(arrowstyle="->",connectionstyle="angle,angleA=0,angleB=90")
    kw = dict(xycoords='data',textcoords="axes fraction",
              arrowprops=arrowprops, bbox=bbox_props, ha="right", va="top")
    ax.annotate(text, xy=(xmin, ymin), xytext=(0.55,0.9), **kw)

annot_min(df.X_k, df.fd_x)

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

def annot_min(x,y,learning_rate, ax=None):
    text= "Learning rate = "+str(learning_rate)
    if not ax:
        ax=plt.gca()
    bbox_props = dict(boxstyle="square,pad=0.3", fc="w", ec="k", lw=0.72)
    arrowprops=dict(arrowstyle="->",connectionstyle="angle,angleA=0,angleB=90")
    kw = dict(xycoords='data',textcoords="axes fraction",
              arrowprops=arrowprops, bbox=bbox_props, ha="right", va="top")
    ax.annotate(text, xy=(1, 1), xytext=(0.55,0.9), **kw)

figure(figsize=(10, 40), dpi=80)
import numpy as np

fig, ax = plt.subplots(2,2,figsize=(15,5))
learning_rate = 0.01
x_k = 0.1
df =gradient_descent(0.3,0.01, 35)
mark = list(range(len(df)))
ax[0,0].plot(mark, df.fd_x, color="red")
annot_min(mark, df.fd_x, 0.01)
print(df.iloc[df.fd_x.idxmin()][1])

learning_rate = 0.02
x_k = 0.1
df =gradient_descent(0.3,0.02, 35)
mark = list(range(len(df)))
ax[0,1].plot(mark, df.fd_x, color="red")
annot_min(mark, df.fd_x, 0.02)
print(df.iloc[df.fd_x.idxmin()][1])

learning_rate = 0.03
x_k = 0.1
df =gradient_descent(0.3,0.03, 35)
mark = list(range(len(df)))
ax[1,0].plot(mark, df.fd_x, color="red")
annot_min(mark, df.fd_x, 0.03)
print(df.iloc[df.fd_x.idxmin()][1])

learning_rate = 0.045
x_k = 0
df =gradient_descent(0.3,0.5, 35)
mark = list(range(len(df)))
ax[1,1].plot(mark, df.fd_x, color="red")
annot_min(mark, df.fd_x, 0.04)
print(df.iloc[df.fd_x.idxmin()][1])
# Out:
# -5.332670857301814
# -5.3286537719915765
# -5.3329636479701055
# -5.326352453704177

# %%
learning_rate = 0.02
x_k = 0.1
df =gradient_descent(0.3,0.05, 35)
fig, ax = plt.subplots()
mark = list(range(len(df)))
ax.plot(mark, df.fd_x, color="red")
annot_min(mark, df.fd_x, learning_rate)

plt.show()

# %%
learning_rate = 0.008
x_k = 0.1
df =gradient_descent(0.3,0.05, 35)
fig, ax = plt.subplots()
mark = list(range(len(df)))
ax.plot(mark, df.fd_x, color="red")
annot_min(mark, df.fd_x, learning_rate)

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

figure(figsize=(10, 40), dpi=80)
import numpy as np

fig, ax = plt.subplots()
mark = list(range(len(df)))
ax.plot(list(range(len(df))), df.fd_x, color="red")
# ax.plot(list(range(len(df))), df.fd_x,markevery=mark, ls="", marker="o", label="points")

ax.arrow(0, 0, 0.5, 0.5, head_width=0.05, head_length=0.1, fc='k', ec='k')

def annot_min(x,y, ax=None):
    xmin = df.fd_x.idxmin()
    ymin = y[df.fd_x.idxmin()]
    text= "x={:.3f}, y={:.3f}".format(xmin, ymin)
    if not ax:
        ax=plt.gca()
    bbox_props = dict(boxstyle="square,pad=0.3", fc="w", ec="k", lw=0.72)
    arrowprops=dict(arrowstyle="->",connectionstyle="angle,angleA=0,angleB=90")
    kw = dict(xycoords='data',textcoords="axes fraction",
              arrowprops=arrowprops, bbox=bbox_props, ha="right", va="top")
    ax.annotate(text, xy=(xmin, ymin), xytext=(0.55,0.9), **kw)

annot_min(df.X_k, df.fd_x)

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

figure(figsize=(10, 40), dpi=80)
import numpy as np

fig, ax = plt.subplots()
mark = list(range(len(df)))
ax.plot(list(range(len(df))), df.fd_x, color="red")
ax.plot(list(range(len(df))), df.fd_x,markevery=mark, ls="", marker="o", label="points")

ax.arrow(0, 0, 0.5, 0.5, head_width=0.05, head_length=0.1, fc='k', ec='k')

def annot_min(x,y, ax=None):
    xmin = x[df.fd_x.idxmin()]
    ymin = y[df.fd_x.idxmin()]
    text= "x={:.3f}, y={:.3f}".format(xmin, ymin)
    if not ax:
        ax=plt.gca()
    bbox_props = dict(boxstyle="square,pad=0.3", fc="w", ec="k", lw=0.72)
    arrowprops=dict(arrowstyle="->",connectionstyle="angle,angleA=0,angleB=90")
    kw = dict(xycoords='data',textcoords="axes fraction",
              arrowprops=arrowprops, bbox=bbox_props, ha="right", va="top")
    ax.annotate(text, xy=(xmin, ymin), xytext=(0.55,0.9), **kw)

annot_min(df.X_k, df.fd_x)

plt.show()

# %%
# Defines a function.
def f(x,y):
    return -(x**2+y**2)+2

# Computes partial derivatives.
def partial_x(f,x,y,h=0.00000001):
    numerator = f(x+h,y) - f(x,y)
    denominator = h
    return numerator/denominator

def partial_y(f,x,y,h=0.00000001):
    numerator = f(x,y+h) - f(x,y)
    denominator = h
    return numerator/denominator

# Computes the gradient of f(x,y).
def calc_gradient(f,x,y):
    return partial_x(f,x,y),partial_y(f,x,y)

# Move a small step towards gradient until magnitude of gradient becomes small.
def gradient_ascent(f,a,b, delta=0.001):
    gradient = calc_gradient(f,a,b)
    while True:
        magnitude = (gradient[0]**2+gradient[1]**2)**(1/2)
        if magnitude<0.001:
            break
        else:
            gradient = calc_gradient(f,a,b)
            a = a + delta*gradient[0]
            b = b + delta*gradient[1]
        
    return "The local max of the function is",str(f(a,b)),"at point",str(a),str(b)

# Test
print(gradient_ascent(f,3,3))
# Out:
# ('The local max of the function is', '1.9999997514846062', 'at point', '0.000352502052322734', '0.000352502052322734')
